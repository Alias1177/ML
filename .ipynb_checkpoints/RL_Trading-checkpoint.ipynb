# %% [markdown]
# <a href="https://colab.research.google.com/github/databyhuseyn/sideProjects/blob/main/RL_Trading.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gym gym-anytrading stable-baselines3

# %%
# !pip install finta
# Out:
# Collecting finta
#   Downloading finta-1.3-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from finta) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from finta) (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->finta) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->finta) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->finta) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->finta) (1.17.0)
# Downloading finta-1.3-py3-none-any.whl (29 kB)
# Installing collected packages: finta
# Successfully installed finta-1.3

# %%
from finta import TA
import gym
import gym_anytrading
from gym_anytrading.envs import StocksEnv

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3 import PPO

# %%
df = pd.read_csv('/content/Download Data - STOCK_US_XNAS_AMZN.csv')

# %%
df.head()
# Out:
#          Date    Open    High     Low   Close      Volume
# 0  03/27/2025  200.89  203.79  199.28  201.36  27,317,660
# 1  03/26/2025  205.84  206.01  199.93  201.13  32,990,969
# 2  03/25/2025  203.60  206.21  203.22  205.71  31,171,160
# 3  03/24/2025  200.00  203.64  199.95  203.26  41,625,367
# 4  03/21/2025  192.90  196.99  192.52  196.21  60,056,922

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251 entries, 0 to 250
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    251 non-null    object
#  1   Open    251 non-null    float64
#  2   High    251 non-null    float64
#  3   Low     251 non-null    float64
#  4   Close   251 non-null    float64
#  5   Volume  251 non-null    object
# dtypes: float64(4), object(2)
# memory usage: 11.9+ KB

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251 entries, 0 to 250
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    251 non-null    datetime64[ns]
#  1   Open    251 non-null    float64
#  2   High    251 non-null    float64
#  3   Low     251 non-null    float64
#  4   Close   251 non-null    float64
#  5   Volume  251 non-null    object
# dtypes: datetime64[ns](1), float64(4), object(1)
# memory usage: 11.9+ KB

# %%
# df['Open'] = pd.to_numeric(df['Open'].str.replace(',',''), downcast='float')
# df['High'] = pd.to_numeric(df['High'].str.replace(',',''), downcast='float')
# df['Low'] = pd.to_numeric(df['Low'].str.replace(',',''), downcast='float')
# df['Close'] = pd.to_numeric(df['Close'].str.replace(',',''), downcast='float')
df['Volume'] = pd.to_numeric(df['Volume'].str.replace(',',''), downcast='float')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251 entries, 0 to 250
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    251 non-null    datetime64[ns]
#  1   Open    251 non-null    float64
#  2   High    251 non-null    float64
#  3   Low     251 non-null    float64
#  4   Close   251 non-null    float64
#  5   Volume  251 non-null    float64
# dtypes: datetime64[ns](1), float64(5)
# memory usage: 11.9 KB

# %%
df.sort_values(by='Date', inplace=True)

# %%
df.set_index('Date', inplace=True)
df.head()
# Out:
#               Open    High     Low   Close      Volume
# Date
# 2024-03-27  179.88  180.00  177.31  179.83  33272551.0
# 2024-03-28  180.17  181.70  179.26  180.38  38051594.0
# 2024-04-01  180.79  183.00  179.95  180.97  29174520.0
# 2024-04-02  179.07  180.79  178.38  180.69  32611551.0
# 2024-04-03  179.90  182.87  179.80  182.41  31046641.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 251 entries, 2024-03-27 to 2025-03-27
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    251 non-null    float64
#  1   High    251 non-null    float64
#  2   Low     251 non-null    float64
#  3   Close   251 non-null    float64
#  4   Volume  251 non-null    float64
# dtypes: float64(5)
# memory usage: 11.8 KB

# %%
df['VWAP'] = TA.VWAP(df)
df['SMA'] = TA.SMA(df,12)
df['EMA'] = TA.EMA(df, 12)
df['WMA'] = TA.WMA(df, 12)
# df['MACD_open'] = TA.MACD(df['Open'])
# df['MACD_high'] = TA.MACD(df['High'])
# df['MACD_low'] = TA.MACD(df['Low'])
# df['MACD_close'] = TA.MACD(df['Close'])
# df['MACD_vol'] = TA.MACD(df['Volume'])
# df['BBANDS_open'] = TA.BBANDS(df['Open'])
# df['BBANDS_high'] = TA.BBANDS(df['High'])
# df['BBANDS_low'] = TA.BBANDS(df['Low'])
# df['BBANDS_close'] = TA.BBANDS(df['Close'])
# df['BBANDS_vol'] = TA.BBANDS(df['Volume'])
# df['KC_open'] = TA.KC(df['Open'])
# df['KC_high'] = TA.KC(df['High'])
# df['KC_low'] = TA.KC(df['Low'])
# df['KC_close'] = TA.KC(df['Close'])
# df['KC_vol'] = TA.KC(df['Volume'])
df['RSI'] = TA.RSI(df)
df['OBV'] = TA.OBV(df)
df['STOCH'] = TA.STOCH(df)
df['CCI'] = TA.CCI(df)
df['MOM'] = TA.MOM(df)
df['SQZMI'] = TA.SQZMI(df)
df['ATR'] = TA.ATR(df)
df['ADL'] = TA.ADL(df)
df['MFI'] = TA.MFI(df)

# %%
df.fillna(0, inplace=True)

# %%
df.isna().sum()
# Out:
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# VWAP      0
# SMA       0
# EMA       0
# WMA       0
# RSI       0
# OBV       0
# STOCH     0
# CCI       0
# MOM       0
# SQZMI     0
# ATR       0
# ADL       0
# MFI       0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'VWAP', 'SMA', 'EMA', 'WMA',
#        'RSI', 'OBV', 'STOCH', 'CCI', 'MOM', 'SQZMI', 'ATR', 'ADL', 'MFI'],
#       dtype='object')

# %%
def add_signals(env):
  start = env.frame_bound[0] - env.window_size
  end = env.frame_bound[1]
  prices = env.df.loc[:, 'Low'].to_numpy()[start:end]
  signal_features = env.df.loc[:, ['Low', 'Volume', 'SMA', 'EMA', 'WMA', 'RSI',
       'VWAP', 'OBV', 'STOCH', 'CCI', 'MOM', 'SQZMI', 'ATR', 'ADL', 'MFI']].to_numpy()[start:end]

  signal_features = signal_features.astype(np.float32)
  return prices, signal_features

# %%
class MyCustomEnv(StocksEnv):
  _process_data = add_signals

env2 = MyCustomEnv(df=df, window_size=12, frame_bound=(12, len(df)))

# %%
env2.prices
# Out:
# array([177.31, 179.26, 179.95, 178.38, 179.8 , 180.  , 181.97, 184.81,
#        184.2 , 182.67, 185.51, 185.08, 183.  , 182.26, 179.82, 178.65,
#        173.44, 174.56, 175.98, 176.18, 166.32, 176.13, 179.39, 174.8 ,
#        176.56, 179.91, 185.42, 184.8 , 187.31, 186.39, 187.44, 186.93,
#        185.36, 183.45, 182.73, 183.46, 183.35, 183.28, 180.75, 181.97,
#        180.08, 180.3 , 179.49, 181.55, 178.36, 173.87, 175.92, 176.44,
#        178.75, 181.49, 183.36, 183.79, 184.54, 185.43, 182.67, 182.23,
#        181.22, 181.43, 182.72, 185.86, 185.33, 185.42, 186.26, 194.2 ,
#        192.5 , 192.82, 195.93, 196.76, 198.17, 197.96, 199.05, 197.69,
#        192.86, 193.83, 190.83, 192.24, 185.99, 181.45, 180.11, 182.48,
#        183.56, 180.41, 176.8 , 180.24, 182.38, 179.38, 184.46, 181.87,
#        160.55, 151.61, 158.54, 161.43, 162.55, 165.85, 166.11, 167.1 ,
#        168.86, 173.99, 176.26, 176.16, 177.43, 178.89, 175.68, 175.24,
#        174.3 , 172.25, 168.92, 170.81, 172.6 , 175.26, 172.54, 175.  ,
#        171.16, 173.51, 176.79, 175.73, 183.54, 185.91, 183.36, 186.14,
#        185.06, 188.47, 187.41, 190.57, 190.13, 192.16, 189.54, 187.34,
#        184.65, 183.45, 184.04, 180.88, 183.6 , 180.25, 180.92, 182.05,
#        185.83, 186.3 , 187.36, 184.58, 185.61, 186.  , 186.28, 186.4 ,
#        186.98, 183.69, 183.86, 187.53, 188.21, 187.82, 192.42, 185.23,
#        197.02, 194.31, 195.99, 199.14, 207.19, 207.44, 205.59, 206.01,
#        209.14, 210.88, 199.61, 200.95, 198.78, 199.45, 195.75, 196.75,
#        199.  , 201.79, 205.05, 204.59, 209.51, 209.65, 215.75, 217.3 ,
#        220.6 , 225.67, 224.2 , 226.26, 227.63, 225.86, 228.01, 227.85,
#        220.11, 222.92, 218.73, 223.9 , 226.13, 226.67, 220.9 , 218.43,
#        218.94, 218.19, 221.62, 224.84, 221.46, 220.2 , 216.5 , 216.47,
#        216.2 , 220.75, 220.31, 223.08, 226.94, 231.19, 231.51, 232.93,
#        225.86, 233.98, 236.15, 232.22, 236.41, 232.9 , 238.03, 235.2 ,
#        236.01, 228.06, 229.2 , 230.13, 228.16, 227.52, 227.23, 223.72,
#        223.71, 221.81, 214.74, 212.42, 204.16, 213.09, 208.37, 206.99,
#        202.55, 197.43, 203.26, 198.3 , 192.53, 190.85, 193.4 , 195.29,
#        191.82, 195.32, 194.32, 189.38, 191.96, 192.3 , 192.52, 199.95,
#        203.22, 199.93, 199.28])

# %%
env2.signal_features
# Out:
# array([[1.7731000e+02, 3.3272552e+07, 0.0000000e+00, ..., 0.0000000e+00,
#         2.9067098e+07, 0.0000000e+00],
#        [1.7925999e+02, 3.8051592e+07, 0.0000000e+00, ..., 0.0000000e+00,
#         2.5948116e+07, 0.0000000e+00],
#        [1.7995000e+02, 2.9174520e+07, 0.0000000e+00, ..., 0.0000000e+00,
#         1.6287045e+07, 0.0000000e+00],
#        ...,
#        [2.0322000e+02, 3.1171160e+07, 1.9717416e+02, ..., 6.4285712e+00,
#         7.6859802e+08, 4.4553993e+01],
#        [1.9992999e+02, 3.2990968e+07, 1.9772333e+02, ..., 6.1442857e+00,
#         7.4862982e+08, 4.5763641e+01],
#        [1.9928000e+02, 2.7317660e+07, 1.9812083e+02, ..., 5.7707143e+00,
#         7.4650982e+08, 4.8221504e+01]], dtype=float32)

# %%
df.head()
# Out:
#               Open    High     Low   Close      Volume        VWAP  SMA  \
# Date
# 2024-03-27  179.88  180.00  177.31  179.83  33272551.0  179.046667  0.0
# 2024-03-28  180.17  181.70  179.26  180.38  38051594.0  179.793570  0.0
# 2024-04-01  180.79  183.00  179.95  180.97  29174520.0  180.232818  0.0
# 2024-04-02  179.07  180.79  178.38  180.69  32611551.0  180.164345  0.0
# 2024-04-03  179.90  182.87  179.80  182.41  31046641.0  180.453520  0.0
#
#                    EMA  WMA         RSI         OBV  STOCH        CCI  MOM  \
# Date
# 2024-03-27  179.830000  0.0    0.000000         0.0    0.0   0.000000  0.0
# 2024-03-28  180.127917  0.0  100.000000  38051594.0    0.0  66.666667  0.0
# 2024-04-01  180.456582  0.0  100.000000  67226114.0    0.0  85.245902  0.0
# 2024-04-02  180.530263  0.0   78.496140  34614563.0    0.0 -22.760291  0.0
# 2024-04-03  181.040981  0.0   91.123509  65661204.0    0.0  99.274406  0.0
#
#             SQZMI  ATR           ADL  MFI
# Date
# 2024-03-27  False  0.0  2.906710e+07  0.0
# 2024-03-28  False  0.0  2.594812e+07  0.0
# 2024-04-01  False  0.0  1.628704e+07  0.0
# 2024-04-02  False  0.0  4.619224e+07  0.0
# 2024-04-03  False  0.0  6.793500e+07  0.0

# %%
env_maker = lambda: env2
env = DummyVecEnv([env_maker])

# %%
model = PPO('MlpPolicy', env, verbose=1)
model.learn(total_timesteps=30000)
# Out:
# Using cuda device
# /usr/local/lib/python3.11/dist-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# -----------------------------
# | time/              |      |
# |    fps             | 696  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 551          |
# |    iterations           | 2            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0067082047 |
# |    clip_fraction        | 0.0271       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.688       |
# |    explained_variance   | -0.0288      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17.6         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00551     |
# |    value_loss           | 48           |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 491          |
# |    iterations           | 3            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0072485493 |
# |    clip_fraction        | 0.0296       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.676       |
# |    explained_variance   | 0.102        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 35.2         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00539     |
# |    value_loss           | 46.3         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 466          |
# |    iterations           | 4            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0038871323 |
# |    clip_fraction        | 0.00679      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.677       |
# |    explained_variance   | 0.287        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.5         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00506     |
# |    value_loss           | 39.5         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 445          |
# |    iterations           | 5            |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0073651746 |
# |    clip_fraction        | 0.0339       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.654       |
# |    explained_variance   | 0.376        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 24.7         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00808     |
# |    value_loss           | 40.1         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 447         |
# |    iterations           | 6           |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.005675119 |
# |    clip_fraction        | 0.0242      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.643      |
# |    explained_variance   | 0.395       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.1        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00794    |
# |    value_loss           | 47.1        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 447          |
# |    iterations           | 7            |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0069318684 |
# |    clip_fraction        | 0.0333       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.622       |
# |    explained_variance   | 0.498        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.5         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00728     |
# |    value_loss           | 34.5         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 441          |
# |    iterations           | 8            |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0050058835 |
# |    clip_fraction        | 0.0385       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.602       |
# |    explained_variance   | 0.486        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.2         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00838     |
# |    value_loss           | 36.9         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 442          |
# |    iterations           | 9            |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0073842322 |
# |    clip_fraction        | 0.0488       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.576       |
# |    explained_variance   | 0.514        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 22.3         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00931     |
# |    value_loss           | 35.7         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 439         |
# |    iterations           | 10          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.003027477 |
# |    clip_fraction        | 0.0726      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.563      |
# |    explained_variance   | 0.558       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.4        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0084     |
# |    value_loss           | 39.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 439         |
# |    iterations           | 11          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.005228542 |
# |    clip_fraction        | 0.0314      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.555      |
# |    explained_variance   | 0.61        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14          |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00707    |
# |    value_loss           | 39          |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 441          |
# |    iterations           | 12           |
# |    time_elapsed         | 55           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0064427005 |
# |    clip_fraction        | 0.047        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.537       |
# |    explained_variance   | 0.61         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 20           |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00935     |
# |    value_loss           | 32.5         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 437         |
# |    iterations           | 13          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.004431592 |
# |    clip_fraction        | 0.0351      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.521      |
# |    explained_variance   | 0.647       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.3        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00541    |
# |    value_loss           | 33.9        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 438          |
# |    iterations           | 14           |
# |    time_elapsed         | 65           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0036306588 |
# |    clip_fraction        | 0.0315       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.51        |
# |    explained_variance   | 0.627        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.6         |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00685     |
# |    value_loss           | 35.5         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 437         |
# |    iterations           | 15          |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.005543042 |
# |    clip_fraction        | 0.0552      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.5        |
# |    explained_variance   | 0.69        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.5        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.009      |
# |    value_loss           | 28.4        |
# -----------------------------------------

# %% [markdown]
# # Eval

# %%
# env = MyCustomEnv(df=df, window_size=12, frame_bound=(12,50))
obs, info = env2.reset()
while True:
    # obs = obs[np.newaxis, ...] # Remove this line or modify it
    obs = obs.reshape(env.num_envs, *env2.shape) # Reshape the observation to match the expected shape
    action, _states = model.predict(obs)
    obs, rewards, done, info = env.step(action)
    if done:
        print("info", info)
        break
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-222-d0206e371698> in <cell line: 0>()
#       3 while True:
#       4     # obs = obs[np.newaxis, ...] # Remove this line or modify it
# ----> 5     obs = obs.reshape(env.num_envs, *env2.shape) # Reshape the observation to match the expected shape
#       6     action, _states = model.predict(obs)
#       7     obs, rewards, done, info = env.step(action)
#
# AttributeError: 'MyCustomEnv' object has no attribute 'num_envs'

# %%
plt.figure(figsize=(15,6))
plt.cla()
env2.render_all()
plt.show()
